# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("/content/all_seasons.csv",index_col=0)
data
# Out:
#             player_name team_abbreviation   age  player_height  player_weight  \
# 0      Randy Livingston               HOU  22.0         193.04      94.800728
# 1      Gaylon Nickerson               WAS  28.0         190.50      86.182480
# 2          George Lynch               VAN  26.0         203.20     103.418976
# 3        George McCloud               LAL  30.0         203.20     102.058200
# 4          George Zidek               DEN  23.0         213.36     119.748288
# ...                 ...               ...   ...            ...            ...
# 12839       Joel Embiid               PHI  29.0         213.36     127.005760
# 12840   John Butler Jr.               POR  20.0         213.36      86.182480
# 12841      John Collins               ATL  25.0         205.74     102.511792
# 12842      Jericho Sims               NYK  24.0         208.28     113.398000
# 12843    JaMychal Green               GSW  33.0         205.74     102.965384
#
# ...

# %%
data.shape
# Out:
# (12844, 21)

# %%
print("Number of teams: ",len(data.	team_abbreviation.unique()))
# Out:
# Number of teams:  36

# %%
data.	team_abbreviation.value_counts()
# Out:
# team_abbreviation
# CLE    450
# TOR    446
# MIA    443
# DAL    443
# LAC    442
# WAS    442
# ATL    439
# PHI    438
# SAS    434
# HOU    433
# LAL    429
# IND    428
# POR    428
# DEN    428
# ORL    428
# MIL    427
# NYK    426
# GSW    426
# BOS    425
# CHI    423
# DET    419
# SAC    418
# MIN    417
# UTA    417
# PHX    415
# MEM    370
# CHA    305
# NJN    257
# OKC    255
# BKN    200
# SEA    182
# NOP    175
# NOH    143
# CHH     89
# VAN     72
# NOK     32
# Name: count, dtype: int64

# %%
print("Average age of each team: ")
data.groupby("team_abbreviation")["age"].mean().sort_values(ascending=False)
# Out:
# Average age of each team:
# team_abbreviation
# CHH    29.056180
# SAS    28.525346
# MIA    28.413093
# DAL    28.146727
# HOU    27.588915
# NYK    27.584507
# LAC    27.470588
# NJN    27.455253
# LAL    27.417249
# MIL    27.402810
# SEA    27.395604
# NOH    27.356643
# BKN    27.155000
# PHX    27.151807
# VAN    27.138889
# DET    27.081146
# UTA    27.011990
# IND    26.978972
# TOR    26.899103
# CLE    26.864444
# GSW    26.828638
# WAS    26.782805
# CHI    26.747045
# ATL    26.712984
# ORL    26.670561
# MIN    26.669065
# SAC    26.667464
# BOS    26.632941
# NOK    26.625000
# DEN    26.614486
# PHI    26.509132
# NOP    26.394286
# POR    26.366822
# MEM    26.072973
# CHA    26.045902
# OKC    25.631373
# Name: age, dtype: float64

# %%
sns.histplot(data,x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
print("Maximum height: ",data["player_height"].max(),"cm")
print("Minimum height: ",data["player_height"].min(),"cm")
# Out:
# Maximum height:  231.14 cm
# Minimum height:  160.02 cm

# %%
sns.histplot(data,x="player_height")
# Out:
# <Axes: xlabel='player_height', ylabel='Count'>
